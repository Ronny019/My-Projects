# %%
import os
import zipfile

local_zip = '/tmp/4_pokemons.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/')
zip_ref.close()

# %%
import tensorflow as tf
import keras_preprocessing
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "/tmp/4_pokemons/train"
training_datagen = ImageDataGenerator(
      rescale = 1./255,
	    rotation_range=40,
      width_shift_range=0.2,
      height_shift_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

VALIDATION_DIR = "/tmp/4_pokemons/validation"
validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = training_datagen.flow_from_directory(
	TRAINING_DIR,
	target_size=(200,200),
	class_mode='categorical',
  batch_size=64
)

validation_generator = validation_datagen.flow_from_directory(
	VALIDATION_DIR,
	target_size=(200,200),
	class_mode='categorical',
  batch_size=64
)

model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(200, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(3000,activation='relu'),
    #tf.keras.layers.Dropout(0.2),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])


model.summary()

adam =tf.keras.optimizers.Adam(learning_rate=0.00001)

model.compile(loss = 'categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

history = model.fit(train_generator, epochs=100, validation_data = validation_generator)

model.save("rps.h5")
# Out:
# Found 593 images belonging to 4 classes.
# Found 116 images belonging to 4 classes.
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_44 (Conv2D)           (None, 198, 198, 64)      1792
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 99, 99, 64)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 97, 97, 64)        36928
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 21, 21, 128)       147584
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12800)             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 3000)              38403000
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               1536512
# _________________________________________________________________
# dense_28 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 40,201,724
# Trainable params: 40,201,724
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  6/10 [=================>............] - ETA: 5s - loss: 1.2835 - accuracy: 0.5045
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 10/10 [==============================] - 19s 2s/step - loss: 1.2599 - accuracy: 0.4857 - val_loss: 1.4905 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 10/10 [==============================] - 17s 2s/step - loss: 1.1724 - accuracy: 0.4890 - val_loss: 1.2674 - val_accuracy: 0.0948
# Epoch 3/100
# 10/10 [==============================] - 18s 2s/step - loss: 1.1427 - accuracy: 0.5700 - val_loss: 1.2314 - val_accuracy: 0.2931
# Epoch 4/100
# 10/10 [==============================] - 17s 2s/step - loss: 1.1048 - accuracy: 0.6408 - val_loss: 1.1503 - val_accuracy: 0.4483
# Epoch 5/100
# 10/10 [==============================] - 18s 2s/step - loss: 1.0550 - accuracy: 0.6796 - val_loss: 0.9774 - val_accuracy: 0.6983
# Epoch 6/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.9967 - accuracy: 0.6948 - val_loss: 0.9167 - val_accuracy: 0.6897
# Epoch 7/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.9260 - accuracy: 0.7201 - val_loss: 0.7871 - val_accuracy: 0.7414
# Epoch 8/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.8625 - accuracy: 0.7268 - val_loss: 0.6667 - val_accuracy: 0.7931
# Epoch 9/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.8256 - accuracy: 0.7251 - val_loss: 0.7235 - val_accuracy: 0.7414
# Epoch 10/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.7714 - accuracy: 0.7538 - val_loss: 0.6347 - val_accuracy: 0.7845
# Epoch 11/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.7331 - accuracy: 0.7572 - val_loss: 0.5582 - val_accuracy: 0.7931
# Epoch 12/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.6944 - accuracy: 0.7622 - val_loss: 0.5353 - val_accuracy: 0.7845
# Epoch 13/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.6543 - accuracy: 0.7774 - val_loss: 0.5422 - val_accuracy: 0.7931
# Epoch 14/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.6320 - accuracy: 0.7774 - val_loss: 0.4800 - val_accuracy: 0.8017
# Epoch 15/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.6019 - accuracy: 0.7808 - val_loss: 0.4788 - val_accuracy: 0.8017
# Epoch 16/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.5861 - accuracy: 0.7808 - val_loss: 0.4082 - val_accuracy: 0.8103
# Epoch 17/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.5609 - accuracy: 0.7825 - val_loss: 0.4287 - val_accuracy: 0.8103
# Epoch 18/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.5415 - accuracy: 0.7825 - val_loss: 0.4497 - val_accuracy: 0.8017
# Epoch 19/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.5152 - accuracy: 0.7909 - val_loss: 0.3511 - val_accuracy: 0.8534
# Epoch 20/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.5306 - accuracy: 0.7926 - val_loss: 0.3461 - val_accuracy: 0.8276
# Epoch 21/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.5109 - accuracy: 0.8010 - val_loss: 0.4776 - val_accuracy: 0.7931
# Epoch 22/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4781 - accuracy: 0.8061 - val_loss: 0.3790 - val_accuracy: 0.8017
# Epoch 23/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4562 - accuracy: 0.8280 - val_loss: 0.4026 - val_accuracy: 0.8190
# Epoch 24/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4608 - accuracy: 0.8331 - val_loss: 0.3975 - val_accuracy: 0.8103
# Epoch 25/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4498 - accuracy: 0.8280 - val_loss: 0.3828 - val_accuracy: 0.8276
# Epoch 26/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4281 - accuracy: 0.8331 - val_loss: 0.4191 - val_accuracy: 0.8190
# Epoch 27/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4222 - accuracy: 0.8550 - val_loss: 0.3572 - val_accuracy: 0.8621
# Epoch 28/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4146 - accuracy: 0.8364 - val_loss: 0.3651 - val_accuracy: 0.8190
# Epoch 29/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4439 - accuracy: 0.8398 - val_loss: 0.3961 - val_accuracy: 0.8276
# Epoch 30/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.4247 - accuracy: 0.8432 - val_loss: 0.3693 - val_accuracy: 0.8448
# Epoch 31/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3888 - accuracy: 0.8617 - val_loss: 0.3258 - val_accuracy: 0.8448
# Epoch 32/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3897 - accuracy: 0.8634 - val_loss: 0.3633 - val_accuracy: 0.8276
# Epoch 33/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.4122 - accuracy: 0.8718 - val_loss: 0.5276 - val_accuracy: 0.7759
# Epoch 34/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3973 - accuracy: 0.8600 - val_loss: 0.2688 - val_accuracy: 0.8793
# Epoch 35/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3673 - accuracy: 0.8702 - val_loss: 0.3660 - val_accuracy: 0.8707
# Epoch 36/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3608 - accuracy: 0.8786 - val_loss: 0.3341 - val_accuracy: 0.8534
# Epoch 37/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3918 - accuracy: 0.8718 - val_loss: 0.3546 - val_accuracy: 0.8621
# Epoch 38/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3660 - accuracy: 0.8685 - val_loss: 0.2988 - val_accuracy: 0.8879
# Epoch 39/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3714 - accuracy: 0.8752 - val_loss: 0.3377 - val_accuracy: 0.8707
# Epoch 40/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3881 - accuracy: 0.8769 - val_loss: 0.3966 - val_accuracy: 0.8534
# Epoch 41/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3624 - accuracy: 0.8853 - val_loss: 0.3452 - val_accuracy: 0.8534
# Epoch 42/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3467 - accuracy: 0.8702 - val_loss: 0.3411 - val_accuracy: 0.9310
# Epoch 43/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3506 - accuracy: 0.8870 - val_loss: 0.3196 - val_accuracy: 0.8534
# Epoch 44/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3495 - accuracy: 0.8718 - val_loss: 0.3355 - val_accuracy: 0.8793
# Epoch 45/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3567 - accuracy: 0.8718 - val_loss: 0.3248 - val_accuracy: 0.9224
# Epoch 46/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3560 - accuracy: 0.8904 - val_loss: 0.4680 - val_accuracy: 0.8017
# Epoch 47/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3422 - accuracy: 0.8836 - val_loss: 0.3140 - val_accuracy: 0.8793
# Epoch 48/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3305 - accuracy: 0.8938 - val_loss: 0.3962 - val_accuracy: 0.8448
# Epoch 49/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3573 - accuracy: 0.8954 - val_loss: 0.3423 - val_accuracy: 0.8793
# Epoch 50/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3273 - accuracy: 0.8988 - val_loss: 0.3083 - val_accuracy: 0.9138
# Epoch 51/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3284 - accuracy: 0.8971 - val_loss: 0.3251 - val_accuracy: 0.8879
# Epoch 52/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3409 - accuracy: 0.8988 - val_loss: 0.3585 - val_accuracy: 0.8621
# Epoch 53/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3462 - accuracy: 0.8870 - val_loss: 0.4507 - val_accuracy: 0.8362
# Epoch 54/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.3471 - accuracy: 0.8904 - val_loss: 0.3625 - val_accuracy: 0.9138
# Epoch 55/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3293 - accuracy: 0.9005 - val_loss: 0.3529 - val_accuracy: 0.9052
# Epoch 56/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3246 - accuracy: 0.8921 - val_loss: 0.2966 - val_accuracy: 0.8966
# Epoch 57/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3512 - accuracy: 0.8870 - val_loss: 0.4219 - val_accuracy: 0.8362
# Epoch 58/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.3287 - accuracy: 0.8887 - val_loss: 0.3382 - val_accuracy: 0.9224
# Epoch 59/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3302 - accuracy: 0.8820 - val_loss: 0.3477 - val_accuracy: 0.8707
# Epoch 60/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3442 - accuracy: 0.8938 - val_loss: 0.3101 - val_accuracy: 0.9224
# Epoch 61/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.3138 - accuracy: 0.9005 - val_loss: 0.3373 - val_accuracy: 0.8879
# Epoch 62/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3048 - accuracy: 0.8954 - val_loss: 0.3232 - val_accuracy: 0.8966
# Epoch 63/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3157 - accuracy: 0.8870 - val_loss: 0.3305 - val_accuracy: 0.8793
# Epoch 64/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3287 - accuracy: 0.8887 - val_loss: 0.2616 - val_accuracy: 0.9310
# Epoch 65/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3124 - accuracy: 0.9039 - val_loss: 0.3086 - val_accuracy: 0.8707
# Epoch 66/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3239 - accuracy: 0.8752 - val_loss: 0.3699 - val_accuracy: 0.8879
# Epoch 67/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3441 - accuracy: 0.8769 - val_loss: 0.2986 - val_accuracy: 0.9310
# Epoch 68/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3162 - accuracy: 0.8752 - val_loss: 0.3423 - val_accuracy: 0.8448
# Epoch 69/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3293 - accuracy: 0.8954 - val_loss: 0.3026 - val_accuracy: 0.9138
# Epoch 70/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3553 - accuracy: 0.8904 - val_loss: 0.4766 - val_accuracy: 0.8621
# Epoch 71/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3311 - accuracy: 0.9106 - val_loss: 0.3472 - val_accuracy: 0.8707
# Epoch 72/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3081 - accuracy: 0.9056 - val_loss: 0.2945 - val_accuracy: 0.8966
# Epoch 73/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3165 - accuracy: 0.8803 - val_loss: 0.2774 - val_accuracy: 0.9224
# Epoch 74/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3171 - accuracy: 0.8904 - val_loss: 0.3312 - val_accuracy: 0.8879
# Epoch 75/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3091 - accuracy: 0.9123 - val_loss: 0.2792 - val_accuracy: 0.9224
# Epoch 76/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3241 - accuracy: 0.9005 - val_loss: 0.2295 - val_accuracy: 0.9224
# Epoch 77/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2995 - accuracy: 0.8921 - val_loss: 0.3566 - val_accuracy: 0.8793
# Epoch 78/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3131 - accuracy: 0.9022 - val_loss: 0.2449 - val_accuracy: 0.9310
# Epoch 79/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3243 - accuracy: 0.8938 - val_loss: 0.3858 - val_accuracy: 0.8621
# Epoch 80/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3043 - accuracy: 0.8971 - val_loss: 0.3279 - val_accuracy: 0.8879
# Epoch 81/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3135 - accuracy: 0.8904 - val_loss: 0.2466 - val_accuracy: 0.9224
# Epoch 82/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.3332 - accuracy: 0.8938 - val_loss: 0.4131 - val_accuracy: 0.8621
# Epoch 83/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3092 - accuracy: 0.9039 - val_loss: 0.2208 - val_accuracy: 0.9397
# Epoch 84/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3154 - accuracy: 0.8954 - val_loss: 0.2693 - val_accuracy: 0.9138
# Epoch 85/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3085 - accuracy: 0.9157 - val_loss: 0.2998 - val_accuracy: 0.9052
# Epoch 86/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2815 - accuracy: 0.9039 - val_loss: 0.2461 - val_accuracy: 0.9397
# Epoch 87/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.2775 - accuracy: 0.9140 - val_loss: 0.3174 - val_accuracy: 0.8966
# Epoch 88/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2961 - accuracy: 0.9191 - val_loss: 0.2509 - val_accuracy: 0.9224
# Epoch 89/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2796 - accuracy: 0.9039 - val_loss: 0.3048 - val_accuracy: 0.9138
# Epoch 90/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3119 - accuracy: 0.8870 - val_loss: 0.3393 - val_accuracy: 0.8793
# Epoch 91/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2980 - accuracy: 0.8954 - val_loss: 0.2528 - val_accuracy: 0.9310
# Epoch 92/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.2944 - accuracy: 0.9073 - val_loss: 0.3017 - val_accuracy: 0.8966
# Epoch 93/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.2906 - accuracy: 0.9056 - val_loss: 0.2510 - val_accuracy: 0.9310
# Epoch 94/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.2849 - accuracy: 0.9140 - val_loss: 0.3353 - val_accuracy: 0.8879
# Epoch 95/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.2869 - accuracy: 0.9106 - val_loss: 0.2357 - val_accuracy: 0.9224
# Epoch 96/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2637 - accuracy: 0.9106 - val_loss: 0.3632 - val_accuracy: 0.8879
# Epoch 97/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2999 - accuracy: 0.9022 - val_loss: 0.2074 - val_accuracy: 0.9397
# Epoch 98/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.3098 - accuracy: 0.8988 - val_loss: 0.3144 - val_accuracy: 0.9052
# Epoch 99/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2802 - accuracy: 0.9005 - val_loss: 0.2807 - val_accuracy: 0.9138
# Epoch 100/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.2813 - accuracy: 0.9073 - val_loss: 0.2652 - val_accuracy: 0.9310

# %%
from google.colab import files
files.download('rps.h5')
